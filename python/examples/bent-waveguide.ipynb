# %% [markdown]
# # A 90° Bend

# %% [markdown]
# We'll start a new simulation where we look at the fields propagating through a waveguide bend, and we'll do a couple of other things differently as well.
#
# As usual, the first thing to do is to load the Meep library:

# %%
import meep as mp
from matplotlib import pyplot as plt
import numpy as np
from IPython.display import Video

# %matplotlib inline

# %% [markdown]
# Then let's set up the bent waveguide in a slightly larger cell:

# %%
cell = mp.Vector3(16, 16, 0)
geometry = [
    mp.Block(
        mp.Vector3(12, 1, mp.inf),
        center=mp.Vector3(-2.5, -3.5),
        material=mp.Medium(epsilon=12),
    ),
    mp.Block(
        mp.Vector3(1, 12, mp.inf),
        center=mp.Vector3(3.5, 2),
        material=mp.Medium(epsilon=12),
    ),
]
pml_layers = [mp.PML(1.0)]
resolution = 10

# %% [markdown]
# Note that we have two blocks, both off-center to produce the bent waveguide structure pictured below. As illustrated in the figure, the origin (0,0) of the coordinate system is at the center of the cell, with positive $y$ being downwards, and thus the block of size 12$\times$1 is centered at (-2,-3.5). Also shown in green is the source plane at $x=−7$ which is shifted to $y=−3.5$ so that it is still inside the waveguide.

# %% [markdown]
# There are a couple of items to note. First, a point source does not couple very efficiently to the waveguide mode, so we'll expand this into a line source, centered at (-7,-3.5), with the same width as the waveguide by adding a `size` property to the source. This is shown in green in the figure above. An eigenmode source can also be used which is described in Tutorial/Optical Forces. Second, instead of turning the source on suddenly at t=0 which excites many other frequencies because of the discontinuity, we will ramp it on slowly. Meep uses a hyperbolic tangent (tanh) turn-on function over a time proportional to the `width` of 20 time units which is a little over three periods. Finally, just for variety, we'll specify the vacuum wavelength instead of the frequency; again, we'll use a wavelength such that the waveguide is half a wavelength wide.

# %%
sources = [
    mp.Source(
        mp.ContinuousSource(wavelength=2 * (11**0.5), width=20),
        component=mp.Ez,
        center=mp.Vector3(-7, -3.5),
        size=mp.Vector3(0, 1),
    )
]

# %% [markdown]
# Now we'll set up and visualize the simulation domain.

# %%
sim = mp.Simulation(
    cell_size=cell,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
)

# %%
f = plt.figure(dpi=150)
sim.plot2D(ax=f.gca())
plt.show()
# Out:
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,2,0)
#           size (1,12,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)

# %% [markdown]
# As we expect, we see the bent waveguide structure with PML boundaries (green) and a source (red) with the same size as the waveguide width.

# %%
f = plt.figure(dpi=150)
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)
sim.run(mp.at_every(0.5, Animate), until=100)
plt.close()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000108957 s
# Working in 2D dimensions.
# Computational cell is 16 x 16 x 0 with resolution 10
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,2,0)
#           size (1,12,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.019958 s
# -----------
# FloatProgress(value=0.0, description='0% done ')
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,2,0)
#           size (1,12,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# Normalizing field data...
# run 0 finished at t = 100.0 (2000 timesteps)

# %%
filename = "media/bent_waveguide_2.mp4"
fps = 10
Animate.to_mp4(fps, filename)
Video(filename)
# Out:
# Generating MP4...
# <video src="media/bent_waveguide_2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# It is clear that the transmission around the bend is rather low for this frequency and structure — both large reflection and large radiation loss are clearly visible. Moreover, since we are operating just barely below the cutoff for single-mode behavior, we are able to excite a second leaky mode after the waveguide bend, whose second-order mode pattern (superimposed with the fundamental mode) is apparent in the animation.
#
# Below, we show a field snapshot from a simulation with a larger cell along the y direction, in which you can see that the second-order leaky mode decays away, leaving us with the fundamental mode propagating upward.

# %%
sim.reset_meep()
cell = mp.Vector3(16, 40, 0)
geometry = [
    mp.Block(
        mp.Vector3(12, 1, mp.inf),
        center=mp.Vector3(-2.5, -3.5),
        material=mp.Medium(epsilon=12),
    ),
    mp.Block(
        mp.Vector3(1, 42, mp.inf),
        center=mp.Vector3(3.5, 17),
        material=mp.Medium(epsilon=12),
    ),
]
sim.cell_size = cell
sim.geometry = geometry
sim.geometry_center = mp.Vector3(0, 12, 0)

sim.run(until=400)

plt.figure(dpi=150)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 16 x 40 x 0 with resolution 10
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,17,0)
#           size (1,42,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.0377221 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=400.0)
# run 1 finished at t = 400.0 (8000 timesteps)
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,17,0)
#           size (1,42,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)

# %% [markdown]
# Instead of doing an animation, another interesting possibility is to make an image from a $x\times t$ slice. To get the $y=−3.5$ slice, which gives us an image of the fields in the first waveguide branch as a function of time, we can use `get_array` in a step function to collect a slice for each time step

# %%
vals = []


def get_slice(sim):
    vals.append(
        sim.get_array(
            center=mp.Vector3(0, -3.5), size=mp.Vector3(16, 0), component=mp.Ez
        )
    )


sim.reset_meep()
#sim.run(mp.at_beginning(mp.output_epsilon), mp.at_every(0.6, get_slice), until=200)

# output into media
sim.use_output_directory()
sim.run(mp.at_every(0.6 , mp.output_png(mp.Ez, "-Zc dkbluered")), until=200)

plt.figure(dpi=150)
plt.imshow(vals, interpolation="spline36", cmap="RdBu")
plt.axis("off")
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000102997 s
# Working in 2D dimensions.
# Computational cell is 16 x 40 x 0 with resolution 10
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,17,0)
#           size (1,42,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.0387321 s
# -----------
# Meep: using output directory '-out'
# FloatProgress(value=0.0, description='0% done ', max=200.0)
# creating output file "-out/ez-000000.60.h5"...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 17
#      13 #sim.run(mp.at_beginning(mp.output_epsilon), mp.at_every(0.6, get_slice), until=200)
#      14
#      15 # output into media
#      16 sim.use_output_directory()
# ---> 17 sim.run(mp.at_every(0.6 , mp.output_png(mp.Ez, "-Zc dkbluered")), until=200)
#      19 plt.figure(dpi=150)
#      20 plt.imshow(vals, interpolation="spline36", cmap="RdBu")
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:4538, in Simulation.run(self, *step_funcs, **kwargs)
#    4536     self._run_sources_until(until_after_sources, step_funcs)
#    4537 elif until is not None:
# -> 4538     self._run_until(until, step_funcs)
#    4539 else:
#    4540     raise ValueError("Invalid run configuration")
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:2833, in Simulation._run_until(self, cond, step_funcs)
#    2831 while not any([x(self) for x in cond]):
#    2832     for func in step_funcs:
# -> 2833         _eval_step_func(self, func, "step")
#    2834     self.fields.step()
#    2836 # Translating the recursive scheme version of run-until into an iterative version
#    2837 # (because python isn't tail-call-optimized) means we need one extra iteration to
#    2838 # be the same as scheme.
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:5008, in _eval_step_func(sim, func, todo)
#    5006         func(sim)
#    5007 elif num_args == 2:
# -> 5008     func(sim, todo)
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:5107, in at_every.<locals>._every(sim, todo)
#    5105 if todo == "finish" or t >= closure["tlast"] + dt + (-0.5 * sim.fields.dt):
#    5106     for func in step_funcs:
# -> 5107         _eval_step_func(sim, func, todo)
#    5108     closure["tlast"] = t
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:5008, in _eval_step_func(sim, func, todo)
#    5006         func(sim)
#    5007 elif num_args == 2:
# -> 5008     func(sim, todo)
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:5566, in output_png.<locals>._output_png(sim, todo)
#    5560 closure["maxabs"] = max(closure["maxabs"], sim.fields.max_abs(compnt, ov))
#    5561 convert = sim.h5topng(
#    5562     rm_h5,
#    5563     "-M {} {}".format(closure["maxabs"], options),
#    5564     lambda sim: sim.output_component(compnt),
#    5565 )
# -> 5566 convert(sim, todo)
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:5523, in convert_h5.<locals>._convert_h5(sim, todo)
#    5520 sim.output_h5_hook = convert
#    5522 for f in step_funcs:
# -> 5523     _eval_step_func(sim, f, todo)
#    5525 sim.output_h5_hook = hooksave
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:5006, in _eval_step_func(sim, func, todo)
#    5004 elif num_args == 1:
#    5005     if todo == "step":
# -> 5006         func(sim)
#    5007 elif num_args == 2:
#    5008     func(sim, todo)
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:5564, in output_png.<locals>._output_png.<locals>.<lambda>(sim)
#    5558     ov = sim.output_volume
#    5560 closure["maxabs"] = max(closure["maxabs"], sim.fields.max_abs(compnt, ov))
#    5561 convert = sim.h5topng(
#    5562     rm_h5,
#    5563     "-M {} {}".format(closure["maxabs"], options),
# -> 5564     lambda sim: sim.output_component(compnt),
#    5565 )
#    5566 convert(sim, todo)
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:3837, in Simulation.output_component(self, c, h5file, frequency)
#    3835 if c == mp.Dielectric:
#    3836     self.last_eps_filename = nm
# -> 3837 self.output_h5_hook(nm)
#
# File /opt/anaconda3/envs/meep/lib/python3.13/site-packages/meep/simulation.py:5514, in convert_h5.<locals>.convert(fname)
#    5512 cmd = convert_cmd.split()
#    5513 cmd.append(fname)
# -> 5514 ret = subprocess.call(cmd)
#    5515 if ret == 0 and rm_h5:
#    5516     os.remove(fname)
#
# File /opt/anaconda3/envs/meep/lib/python3.13/subprocess.py:395, in call(timeout, *popenargs, **kwargs)
#     387 def call(*popenargs, timeout=None, **kwargs):
#     388     """Run command with arguments.  Wait for command to complete or
#     389     for timeout seconds, then return the returncode attribute.
#     390
#    (...)    393     retcode = call(["ls", "-l"])
#     394     """
# --> 395     with Popen(*popenargs, **kwargs) as p:
#     396         try:
#     397             return p.wait(timeout=timeout)
#
# File /opt/anaconda3/envs/meep/lib/python3.13/subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035         if self.text_mode:
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#    1050     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /opt/anaconda3/envs/meep/lib/python3.13/subprocess.py:1972, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1970     err_msg = os.strerror(errno_num)
#    1971 if err_filename is not None:
# -> 1972     raise child_exception_type(errno_num, err_msg, err_filename)
#    1973 else:
#    1974     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'h5topng'
